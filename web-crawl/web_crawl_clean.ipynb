# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r"C:\Users\Tyller Sun\all_cata.csv")

# %%
data
# Out:
#        Unnamed: 0         0     1           2         3  \
# 0               0  \n\n首頁\n  進口食品         義大利   咖啡粉/咖啡豆
# 1               1  \n\n首頁\n  進口食品         義大利   咖啡粉/咖啡豆
# 2               2  \n\n首頁\n  進口食品         義大利   咖啡粉/咖啡豆
# 3               3  \n\n首頁\n  進口食品         義大利   咖啡粉/咖啡豆
# 4               4  \n\n首頁\n  進口食品         義大利   咖啡粉/咖啡豆
# ...           ...       ...   ...         ...       ...
# 16180       16180      首頁\n  免運專區          其他        其他
# 16181       16181      首頁\n  免運專區          其他        其他
# 16182       16182      首頁\n  免運專區          其他        其他
# 16183       16183      首頁\n  廚房用品  濾水壺/淨水器/濾心  Brita濾水壺
# 16184       16184      首頁\n  廚房用品  濾水壺/淨水器/濾心  Brita濾水壺
#
#                                     4    5
# 0              LAVAZZA 經典奶香咖啡豆1KG\n\n  NaN
# 1      LAVAZZA PRONTISSIMO 醇厚即溶咖啡\n\n  NaN
# 2             SEGAFREDO 濃縮咖啡粉250G\n\n  NaN
# 3             SEGAFREDO 中烘咖啡粉250G\n\n  NaN
# 4                LAVAZZA 紅牌咖啡豆1KG\n\n  NaN
# ...

# %%
 for i in range(len(data)):
    data.loc[i,"4"] = (str(data.loc[i,"4"]).strip())

# %%
data
# Out:
#        Unnamed: 0   0     1           2         3                           4  \
# 0               0  首頁  進口食品         義大利   咖啡粉/咖啡豆          LAVAZZA 經典奶香咖啡豆1KG
# 1               1  首頁  進口食品         義大利   咖啡粉/咖啡豆  LAVAZZA PRONTISSIMO 醇厚即溶咖啡
# 2               2  首頁  進口食品         義大利   咖啡粉/咖啡豆         SEGAFREDO 濃縮咖啡粉250G
# 3               3  首頁  進口食品         義大利   咖啡粉/咖啡豆         SEGAFREDO 中烘咖啡粉250G
# 4               4  首頁  進口食品         義大利   咖啡粉/咖啡豆            LAVAZZA 紅牌咖啡豆1KG
# ...           ...  ..   ...         ...       ...                         ...
# 16180       16180  首頁  免運專區          其他        其他              斑馬牌多層飯盒12CM*3層
# 16181       16181  首頁  免運專區          其他        其他            伊娜卡16吋3D立體擺頭商業用扇
# 16182       16182  首頁  免運專區          其他        其他             潔豹 康潔雙格火鍋  30CM
# 16183       16183  首頁  廚房用品  濾水壺/淨水器/濾心  Brita濾水壺         BRITA隨身濾水瓶-米奇綠(共四芯)
# 16184       16184  首頁  廚房用品  濾水壺/淨水器/濾心  Brita濾水壺         BRITA隨身濾水瓶-米妮粉(共四芯)
#
#          5
# 0      NaN
# ...

# %%
data = data.rename(columns={'1': '大分類', '2': '中分類',"3":"細分類", "4":"名稱"})

# %%
data = data.drop(columns = ["Unnamed: 0", "0", "5"])
data
# Out:
#         大分類         中分類       細分類                          名稱
# 0      進口食品         義大利   咖啡粉/咖啡豆          LAVAZZA 經典奶香咖啡豆1KG
# 1      進口食品         義大利   咖啡粉/咖啡豆  LAVAZZA PRONTISSIMO 醇厚即溶咖啡
# 2      進口食品         義大利   咖啡粉/咖啡豆         SEGAFREDO 濃縮咖啡粉250G
# 3      進口食品         義大利   咖啡粉/咖啡豆         SEGAFREDO 中烘咖啡粉250G
# 4      進口食品         義大利   咖啡粉/咖啡豆            LAVAZZA 紅牌咖啡豆1KG
# ...     ...         ...       ...                         ...
# 16180  免運專區          其他        其他              斑馬牌多層飯盒12CM*3層
# 16181  免運專區          其他        其他            伊娜卡16吋3D立體擺頭商業用扇
# 16182  免運專區          其他        其他             潔豹 康潔雙格火鍋  30CM
# 16183  廚房用品  濾水壺/淨水器/濾心  Brita濾水壺         BRITA隨身濾水瓶-米奇綠(共四芯)
# 16184  廚房用品  濾水壺/淨水器/濾心  Brita濾水壺         BRITA隨身濾水瓶-米妮粉(共四芯)
#
# [16185 rows x 4 columns]

# %%
data = data.rename(columns={1: '大分類', 2: '中分類',3:"細分類", 4:"名稱"})

# %%
data
# Out:
#        大分類   中分類      細分類                          名稱
# 0     進口食品   義大利  咖啡粉/咖啡豆          LAVAZZA 經典奶香咖啡豆1KG
# 1     進口食品   義大利  咖啡粉/咖啡豆  LAVAZZA PRONTISSIMO 醇厚即溶咖啡
# 2     進口食品   義大利  咖啡粉/咖啡豆         SEGAFREDO 濃縮咖啡粉250G
# 3     進口食品   義大利  咖啡粉/咖啡豆         SEGAFREDO 中烘咖啡粉250G
# 4     進口食品   義大利  咖啡粉/咖啡豆            LAVAZZA 紅牌咖啡豆1KG
# ...    ...   ...      ...                         ...
# 8413  居家清潔  家庭清潔    地板清潔劑          魔術靈地板清潔劑忘憂松林2000ML
# 8414  居家清潔  家庭清潔     萬用清潔                 妙管家水垢殺手750g
# 8415  居家清潔  家庭清潔     餐具清潔                橘子工坊橘油泡泡食器清潔
# 8416  居家清潔  家庭清潔    芳香/除臭        Farcent衣物香氛袋-小蒼蘭&英國梨
# 8417  居家清潔  家庭清潔    芳香/除臭         Farcent衣物香氛袋-鼠尾草&海鹽
#
# [8418 rows x 4 columns]

# %%
for i in range(len(data)):
    data.loc[i,"名稱"] = (str(data.loc[i,"名稱"]).strip())

# %%
for i in range(len(data)):
    data.loc[i,"細分類"] = (str(data.loc[i,"細分類"]).strip())

# %%
def get_num_of_null(data):
    count = 0
    true_false = pd.isnull(data)
    for i in range(len(true_false)):
        if true_false[i] == False:
            count = count + 1
    print(count)

get_num_of_null(data["名稱"])
# Out:
# 16185

# %%
data.to_csv("new_half_data.csv", encoding='utf_8_sig')

# %%
for i in range(len(data)):
    if data["名稱"][i] == "nan":
        if  data["細分類"][i] == "nan":
            print(data["中分類"][i])
            if data["中分類"][i] =="nan":
                print(data["大分類"][i])
                data["名稱"][i] = data["大分類"][i]
            # print(data["中分類"][i])
            else:
                data["名稱"][i] = data["中分類"][i]
        else :
            data["名稱"][i] = data["細分類"][i]
# Out:
# nan
# 史雲生清雞湯 500ml
# nan
# 嬌生嬰兒活力清新洗髮露500ml
# nan
# 嬌生嬰兒活力亮澤洗髮露500ml
# nan
# 優生超厚乾濕兩用純棉巾90抽(區)
# nan
# baby磁性學習板
# nan
# 禾聯5.0 kw變頻冷暖氣
# nan
# 禾聯 2.3kw變頻冷暖氣_客訂商品無法指定到貨日期

# %%
data.to_csv("new_half_data.csv", encoding='utf_8_sig')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
r = data.groupby("大分類")

# %%
r.count()
# Out:
#                     中分類   細分類    名稱
# 大分類
# 優生超厚乾濕兩用純棉巾90抽(區)     0     1     1
# 免運專區                  3     3     3
# 史雲生清雞湯 500ml          0     1     1
# 嬌生嬰兒活力亮澤洗髮露500ml      0     1     1
# 嬌生嬰兒活力清新洗髮露500ml      0     1     1
# 嬰幼兒與孕婦              180   180   180
# 寵物                  339   339   339
# 居家清潔                284   284   284
# 廚房用品                 13    13    13
# 抗菌專區                 14    14    14
# 服飾與配件精品               1     1     1
# 泡麵罐頭                630   630   630
# 美容沐浴               2220  2220  2220
# 進口食品                212   212   212
# 零食點心               1634  1634  1634
# 食品雜貨               1685  1685  1685
# 飲料沖泡               1199  1199  1199
